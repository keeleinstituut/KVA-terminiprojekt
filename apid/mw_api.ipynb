# %%
from mw.entries_requests import get_data
import json

# %% [markdown]
# # Merriam-Webster Collegiate Dictionary

# %%
result = get_data("war", "collegiate")

if result:

    print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "meta": {
#       "id": "war:1",
#       "uuid": "375c6df5-d281-4811-9a53-a31096f8c9f0",
#       "sort": "230023600",
#       "src": "collegiate",
#       "section": "alpha",
#       "stems": [
#         "war",
#         "warless",
#         "wars"
#       ],
#       "offensive": false
#     },
#     "hom": 1,
#     "hwi": {
#       "hw": "war",
#       "prs": [
#         {
#           "mw": "ˈwȯr",
#           "sound": {
#             "audio": "war00001",
#             "ref": "c",
#             "stat": "1"
#           }
#         }
#       ]
#     },
#     "fl": "noun",
#     "lbs": [
#       "often attributive"
#     ],
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "pseq",
#               [
#                 [
#                   "sense",
#                   {
#                     "sn": "1 a (1)",
#                     "dt": [
#                       [
#                         "text",
#                         "{bc}a state of usually open and declared armed hostile conflict between states or nations"
#                       ]
#                     ]
#                   }
#                 ],
#                 [
#                   "sense",
#                   {
#                     "sn": "(2)",
#                     "dt": [
#                       [
#                         "text",
#                         "{bc}a period of such armed conflict"
#                       ]
#                     ]
#                   }
#                 ],
#                 [
#                   "sense",
#                   {
#                     "sn": "(3)",
#                     "dt": [
#                       [
#                         "text",
#                         "{bc}{sx|state of war||}"
#                       ]
#                     ]
#                   }
#                 ]
#               ]
#             ],
#             [
#               "sense",
#               {
#                 "sn": "b",
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}the art or science of warfare"
#                   ]
#                 ]
#               }
#             ],
#             [
#               "pseq",
#               [
#                 [
#                   "sense",
#                   {
#                     "sn": "c (1)",
#                     "sls": [
#                       "obsolete"
#                     ],
#                     "dt": [
#                       [
#                         "text",
#                         "{bc}weapons and equipment for war"
#                       ]
#                     ]
#                   }
#                 ],
#                 [
#                   "sense",
#                   {
#                     "sn": "(2)",
#                     "sls": [
#                       "archaic"
#                     ],
#                     "dt": [
#                       [
#                         "text",
#                         "{bc}soldiers armed and equipped for war"
#                       ]
#                     ]
#                   }
#                 ]
#               ]
#             ]
#           ],
#           [
#             [
#               "sense",
#               {
#                 "sn": "2 a",
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}a state of hostility, conflict, or antagonism"
#                   ]
#                 ]
#               }
#             ],
#             [
#               "sense",
#               {
#                 "sn": "b",
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}a struggle or competition between opposing forces or for a particular end "
#                   ],
#                   [
#                     "vis",
#                     [
#                       {
#                         "t": "a class {wi}war{/wi}"
#                       },
#                       {
#                         "t": "a {wi}war{/wi} against disease"
#                       }
#                     ]
#                   ]
#                 ]
#               }
#             ],
#             [
#               "sense",
#               {
#                 "sn": "c",
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}{sx|variance||}, {sx|odds|odds|2}"
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "uros": [
#       {
#         "ure": "war*less",
#         "prs": [
#           {
#             "mw": "ˈwȯr-ləs",
#             "sound": {
#               "audio": "warles01",
#               "ref": "c",
#               "stat": "1"
#             }
#           }
#         ],
#         "fl": "adjective"
#       }
#     ],
#     "et": [
#       [
#         "text",
#         "Middle English {it}werre{/it}, from Anglo-French {it}werre, guerre{/it}, of Germanic origin; akin to Old High German {it}werra{/it} strife; akin to Old High German {it}werran{/it} to confuse"
#       ]
#     ],
#     "date": "12th century{ds||1|a|1}",
#     "shortdef": [
#       "a state of usually open and declared armed hostile conflict between states or nations",
#       "a period of such armed conflict",
#       "state of war"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war:2",
#       "uuid": "b519be65-4d79-4cbe-9696-981d36f51e0d",
#       "sort": "230023700",
#       "src": "collegiate",
#       "section": "alpha",
#       "stems": [
#         "war",
#         "warred",
#         "warring",
#         "wars"
#       ],
#       "offensive": false
#     },
#     "hom": 2,
#     "hwi": {
#       "hw": "war",
#       "prs": [
#         {
#           "mw": "ˈwȯr",
#           "sound": {
#             "audio": "war00001",
#             "ref": "c",
#             "stat": "1"
#           }
#         }
#       ]
#     },
#     "fl": "verb",
#     "ins": [
#       {
#         "if": "warred"
#       },
#       {
#         "if": "war*ring"
#       }
#     ],
#     "def": [
#       {
#         "vd": "intransitive verb",
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "sn": "1",
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}to be in active or vigorous conflict"
#                   ]
#                 ]
#               }
#             ]
#           ],
#           [
#             [
#               "sense",
#               {
#                 "sn": "2",
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}to engage in warfare"
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "date": "13th century{ds||1||}",
#     "shortdef": [
#       "to be in active or vigorous conflict",
#       "to engage in warfare"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war:3",
#       "uuid": "55b5808f-8bc2-46b2-95f9-e7c1ec874e10",
#       "sort": "230023800",
#       "src": "collegiate",
#       "section": "alpha",
#       "stems": [
#         "war"
#       ],
#       "offensive": false
#     },
#     "hom": 3,
#     "hwi": {
#       "hw": "war",
#       "prs": [
#         {
#           "mw": "ˈwär",
#           "sound": {
#             "audio": "war00003",
#             "ref": "c",
#             "stat": "1"
#           }
#         }
#       ]
#     },
#     "fl": "adverb or adjective",
#     "def": [
#       {
#         "sls": [
#           "chiefly Scotland"
#         ],
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}{sx|worse||}"
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "et": [
#       [
#         "text",
#         "Middle English {it}werre{/it}, from Old Norse {it}verri{/it}, adjective, {it}verr{/it}, adverb; akin to Old English {it}wiersa{/it} worse {ma}{mat|worse|}{/ma}"
#       ]
#     ],
#     "date": "13th century",
#     "shortdef": [
#       "worse"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war:4",
#       "uuid": "be388c79-94a2-4183-82e2-4b35d85f4f3f",
#       "sort": "230023900",
#       "src": "collegiate",
#       "section": "alpha",
#       "stems": [
#         "war",
#         "warred",
#         "warring",
#         "wars"
#       ],
#       "offensive": false
#     },
#     "hom": 4,
#     "hwi": {
#       "hw": "war",
#       "prs": [
#         {
#           "mw": "ˈwär",
#           "sound": {
#             "audio": "war00003",
#             "ref": "c",
#             "stat": "1"
#           }
#         }
#       ]
#     },
#     "fl": "verb",
#     "ins": [
#       {
#         "if": "warred"
#       },
#       {
#         "if": "war*ring"
#       }
#     ],
#     "def": [
#       {
#         "vd": "transitive verb",
#         "sls": [
#           "Scotland"
#         ],
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}{sx|worst||}, {sx|overcome||}"
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "date": "15th century",
#     "shortdef": [
#       "worst, overcome"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war baby",
#       "uuid": "e3cb3157-423f-485e-b228-d496615e2329",
#       "sort": "230024000",
#       "src": "collegiate",
#       "section": "alpha",
#       "stems": [
#         "war babies",
#         "war baby"
#       ],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war baby"
#     },
#     "fl": "noun",
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}a person born or conceived during a war"
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "date": "1901",
#     "shortdef": [
#       "a person born or conceived during a war"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war bride",
#       "uuid": "58eaf76a-c875-4de6-9091-b7c61ef488fa",
#       "sort": "230024700",
#       "src": "collegiate",
#       "section": "alpha",
#       "stems": [
#         "war bride",
#         "war brides"
#       ],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war bride"
#     },
#     "fl": "noun",
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "sn": "1",
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}a woman who marries a serviceman ordered into active service in time of war"
#                   ]
#                 ]
#               }
#             ]
#           ],
#           [
#             [
#               "sense",
#               {
#                 "sn": "2",
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}a woman who marries a serviceman especially of a foreign nation met during a time of war"
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "date": "1892{ds||1||}",
#     "shortdef": [
#       "a woman who marries a serviceman ordered into active service in time of war",
#       "a woman who marries a serviceman especially of a foreign nation met during a time of war"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war chest",
#       "uuid": "a0bd8aa0-d25c-4208-8c01-79f863d54609",
#       "sort": "230024800",
#       "src": "collegiate",
#       "section": "alpha",
#       "stems": [
#         "war chest",
#         "war chests"
#       ],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war chest"
#     },
#     "fl": "noun",
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}a fund accumulated to finance a war"
#                   ]
#                 ],
#                 "sdsense": {
#                   "sd": "broadly",
#                   "dt": [
#                     [
#                       "text",
#                       "{bc}a fund earmarked for a specific purpose, action, or campaign"
#                     ]
#                   ]
#                 }
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "date": "1871",
#     "shortdef": [
#       "a fund accumulated to finance a war; broadly : a fund earmarked for a specific purpose, action, or campaign"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war club",
#       "uuid": "6e2f71af-8aca-4d39-85fa-55e189200cd4",
#       "sort": "230024900",
#       "src": "collegiate",
#       "section": "alpha",
#       "stems": [
#         "war club",
#         "war clubs"
#       ],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war club"
#     },
#     "fl": "noun",
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}a club-shaped implement used as a weapon especially by American Indians"
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "date": "1763",
#     "shortdef": [
#       "a club-shaped implement used as a weapon especially by American Indians"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war crime",
#       "uuid": "2e0fea10-c769-46b6-8eaf-a72744d93ec0",
#       "sort": "230025000",
#       "src": "collegiate",
#       "section": "alpha",
#       "stems": [
#         "war crime",
#         "war crimes",
#         "war criminal"
#       ],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war crime"
#     },
#     "fl": "noun",
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}a crime (such as genocide or maltreatment of prisoners) committed during or in connection with war "
#                   ],
#                   [
#                     "uns",
#                     [
#                       [
#                         [
#                           "text",
#                           "usually used in plural"
#                         ]
#                       ]
#                     ]
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "uros": [
#       {
#         "ure": "war criminal",
#         "fl": "noun"
#       }
#     ],
#     "date": "1906",
#     "shortdef": [
#       "a crime (such as genocide or maltreatment of prisoners) committed during or in connection with war —usually used in plural"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war cry",
#       "uuid": "3a90a28d-9376-4ab4-9b14-28b246ab2759",
#       "sort": "230025100",
#       "src": "collegiate",
#       "section": "alpha",
#       "stems": [
#         "war cries",
#         "war cry"
#       ],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war cry"
#     },
#     "fl": "noun",
#     "ins": [
#       {
#         "il": "plural",
#         "if": "war cries"
#       }
#     ],
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "sn": "1",
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}a shouted word, phrase, or sound used by a body of fighters before or in battle {bc}{sx|battle cry||} "
#                   ],
#                   [
#                     "vis",
#                     [
#                       {
#                         "t": "Yelling and shouting fearsome {wi}war cries{/wi}, the attackers leaped from the ditch, peppering the ramparts with a hail of arrows, spears and stones.",
#                         "aq": {
#                           "auth": "Brian Jaques"
#                         }
#                       }
#                     ]
#                   ]
#                 ]
#               }
#             ]
#           ],
#           [
#             [
#               "sense",
#               {
#                 "sn": "2",
#                 "dt": [
#                   [
#                     "text",
#                     "{bc}a slogan, catchphrase, or motto that is used especially to rally people to a cause or to rouse people to action {bc}{sx|rallying cry||} "
#                   ],
#                   [
#                     "vis",
#                     [
#                       {
#                         "t": "Certainly, the NIMBY {wi}war cry{/wi} is being heard in more than my town. The 2006 Saint Index, … which analyzes attitudes toward real estate development, found that twice as many Americans actively oppose development as support it.",
#                         "aq": {
#                           "auth": "Katherine Field"
#                         }
#                       }
#                     ]
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "date": "1748{ds||1||}",
#     "shortdef": [
#       "a shouted word, phrase, or sound used by a body of fighters before or in battle : battle cry",
#       "a slogan, catchphrase, or motto that is used especially to rally people to a cause or to rouse people to action : rallying cry"
#     ]
#   }
# ]

# %% [markdown]
# # Merriam-Webster Collegiate Thesaurus

# %%
result = get_data("war", "thesaurus")

if result:

    print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "meta": {
#       "id": "war",
#       "uuid": "db4a6ea1-f3c6-448c-b26f-4a87375e6452",
#       "src": "coll_thes",
#       "section": "alpha",
#       "target": {
#         "tuuid": "375c6df5-d281-4811-9a53-a31096f8c9f0",
#         "tsrc": "collegiate"
#       },
#       "stems": [
#         "war",
#         "warless",
#         "wars"
#       ],
#       "syns": [
#         [
#           "conflagration",
#           "conflict",
#           "hostilities",
#           "hot war"
#         ],
#         [
#           "conflict",
#           "disaccord",
#           "discord",
#           "discordance",
#           "discordancy",
#           "disharmony",
#           "dissension",
#           "dissent",
#           "dissidence",
#           "dissonance",
#           "disunion",
#           "disunity",
#           "division",
#           "friction",
#           "infighting",
#           "inharmony",
#           "schism",
#           "strife",
#           "variance",
#           "warfare"
#         ],
#         [
#           "ball game",
#           "battle",
#           "combat",
#           "competition",
#           "conflict",
#           "confrontation",
#           "contention",
#           "contest",
#           "dogfight",
#           "duel",
#           "face-off",
#           "grapple",
#           "match",
#           "rivalry",
#           "strife",
#           "struggle",
#           "sweepstakes",
#           "tug-of-war",
#           "warfare"
#         ]
#       ],
#       "ants": [
#         [
#           "peace"
#         ],
#         [
#           "accord",
#           "agreement",
#           "concord",
#           "concordance",
#           "harmony",
#           "peace"
#         ]
#       ],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war"
#     },
#     "fl": "noun",
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "sn": "1",
#                 "dt": [
#                   [
#                     "text",
#                     "a state of armed violent struggle between states, nations, or groups "
#                   ],
#                   [
#                     "vis",
#                     [
#                       {
#                         "t": "the {it}war{/it} was the result of ethnic tensions that had been building in the region for decades"
#                       }
#                     ]
#                   ]
#                 ],
#                 "syn_list": [
#                   [
#                     {
#                       "wd": "conflagration"
#                     },
#                     {
#                       "wd": "conflict"
#                     },
#                     {
#                       "wd": "hostilities"
#                     },
#                     {
#                       "wd": "hot war"
#                     }
#                   ]
#                 ],
#                 "rel_list": [
#                   [
#                     {
#                       "wd": "civil war"
#                     },
#                     {
#                       "wd": "cold war"
#                     },
#                     {
#                       "wd": "holy war"
#                     },
#                     {
#                       "wd": "limited war"
#                     },
#                     {
#                       "wd": "police action"
#                     },
#                     {
#                       "wd": "world war"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "action"
#                     },
#                     {
#                       "wd": "battle"
#                     },
#                     {
#                       "wd": "engagement"
#                     },
#                     {
#                       "wd": "skirmish"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "combat"
#                     },
#                     {
#                       "wd": "fighting"
#                     },
#                     {
#                       "wd": "warfare"
#                     }
#                   ]
#                 ],
#                 "near_list": [
#                   [
#                     {
#                       "wd": "demilitarization"
#                     },
#                     {
#                       "wd": "demobilization"
#                     },
#                     {
#                       "wd": "disarmament"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "pacification"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "cease-fire"
#                     },
#                     {
#                       "wd": "truce"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "calm"
#                     },
#                     {
#                       "wd": "peacefulness"
#                     },
#                     {
#                       "wd": "tranquility",
#                       "wvrs": [
#                         {
#                           "wvl": "or",
#                           "wva": "tranquillity"
#                         }
#                       ]
#                     }
#                   ]
#                 ],
#                 "ant_list": [
#                   [
#                     {
#                       "wd": "peace"
#                     }
#                   ]
#                 ]
#               }
#             ]
#           ],
#           [
#             [
#               "sense",
#               {
#                 "sn": "2",
#                 "dt": [
#                   [
#                     "text",
#                     "a lack of agreement or harmony "
#                   ],
#                   [
#                     "vis",
#                     [
#                       {
#                         "t": "the siblings always seemed to be at {it}war{/it} with one another"
#                       }
#                     ]
#                   ]
#                 ],
#                 "syn_list": [
#                   [
#                     {
#                       "wd": "conflict"
#                     },
#                     {
#                       "wd": "disaccord"
#                     },
#                     {
#                       "wd": "discord"
#                     },
#                     {
#                       "wd": "discordance"
#                     },
#                     {
#                       "wd": "discordancy"
#                     },
#                     {
#                       "wd": "disharmony"
#                     },
#                     {
#                       "wd": "dissension",
#                       "wvrs": [
#                         {
#                           "wvl": "also",
#                           "wva": "dissention"
#                         }
#                       ]
#                     },
#                     {
#                       "wd": "dissent"
#                     },
#                     {
#                       "wd": "dissidence"
#                     },
#                     {
#                       "wd": "dissonance"
#                     },
#                     {
#                       "wd": "disunion"
#                     },
#                     {
#                       "wd": "disunity"
#                     },
#                     {
#                       "wd": "division"
#                     },
#                     {
#                       "wd": "friction"
#                     },
#                     {
#                       "wd": "infighting"
#                     },
#                     {
#                       "wd": "inharmony"
#                     },
#                     {
#                       "wd": "schism"
#                     },
#                     {
#                       "wd": "strife"
#                     },
#                     {
#                       "wd": "variance"
#                     },
#                     {
#                       "wd": "warfare"
#                     }
#                   ]
#                 ],
#                 "rel_list": [
#                   [
#                     {
#                       "wd": "clash"
#                     },
#                     {
#                       "wd": "collision"
#                     },
#                     {
#                       "wd": "competition"
#                     },
#                     {
#                       "wd": "contention"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "altercation"
#                     },
#                     {
#                       "wd": "argument"
#                     },
#                     {
#                       "wd": "bicker"
#                     },
#                     {
#                       "wd": "brawl"
#                     },
#                     {
#                       "wd": "debate"
#                     },
#                     {
#                       "wd": "disagreement"
#                     },
#                     {
#                       "wd": "dispute"
#                     },
#                     {
#                       "wd": "divide"
#                     },
#                     {
#                       "wd": "fissure"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "falling-out"
#                     },
#                     {
#                       "wd": "fight"
#                     },
#                     {
#                       "wd": "hassle"
#                     },
#                     {
#                       "wd": "jar"
#                     },
#                     {
#                       "wd": "miff"
#                     },
#                     {
#                       "wd": "mix-up"
#                     },
#                     {
#                       "wd": "quarrel"
#                     },
#                     {
#                       "wd": "row"
#                     },
#                     {
#                       "wd": "run-in"
#                     },
#                     {
#                       "wd": "scrap"
#                     },
#                     {
#                       "wd": "spat"
#                     },
#                     {
#                       "wd": "squabble"
#                     },
#                     {
#                       "wd": "tiff"
#                     },
#                     {
#                       "wd": "wrangle"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "incompatibility"
#                     },
#                     {
#                       "wd": "incongruence"
#                     },
#                     {
#                       "wd": "incongruity"
#                     },
#                     {
#                       "wd": "incongruousness"
#                     },
#                     {
#                       "wd": "inconsistence"
#                     },
#                     {
#                       "wd": "inconsistency"
#                     },
#                     {
#                       "wd": "inconsonance"
#                     },
#                     {
#                       "wd": "inharmoniousness"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "animosity"
#                     },
#                     {
#                       "wd": "antagonism"
#                     },
#                     {
#                       "wd": "antipathy"
#                     },
#                     {
#                       "wd": "cold war"
#                     },
#                     {
#                       "wd": "enmity"
#                     },
#                     {
#                       "wd": "hostility"
#                     },
#                     {
#                       "wd": "ill will"
#                     },
#                     {
#                       "wd": "rancor"
#                     }
#                   ]
#                 ],
#                 "near_list": [
#                   [
#                     {
#                       "wd": "concurrence"
#                     },
#                     {
#                       "wd": "cooperation"
#                     }
#                   ]
#                 ],
#                 "ant_list": [
#                   [
#                     {
#                       "wd": "accord"
#                     },
#                     {
#                       "wd": "agreement"
#                     },
#                     {
#                       "wd": "concord"
#                     },
#                     {
#                       "wd": "concordance"
#                     },
#                     {
#                       "wd": "harmony"
#                     },
#                     {
#                       "wd": "peace"
#                     }
#                   ]
#                 ]
#               }
#             ]
#           ],
#           [
#             [
#               "sense",
#               {
#                 "sn": "3",
#                 "dt": [
#                   [
#                     "text",
#                     "an earnest effort for superiority or victory over another "
#                   ],
#                   [
#                     "vis",
#                     [
#                       {
#                         "t": "only the latest round in the never-ending class {it}war{/it}"
#                       }
#                     ]
#                   ]
#                 ],
#                 "syn_list": [
#                   [
#                     {
#                       "wd": "ball game"
#                     },
#                     {
#                       "wd": "battle"
#                     },
#                     {
#                       "wd": "combat"
#                     },
#                     {
#                       "wd": "competition"
#                     },
#                     {
#                       "wd": "conflict"
#                     },
#                     {
#                       "wd": "confrontation"
#                     },
#                     {
#                       "wd": "contention"
#                     },
#                     {
#                       "wd": "contest"
#                     },
#                     {
#                       "wd": "dogfight"
#                     },
#                     {
#                       "wd": "duel"
#                     },
#                     {
#                       "wd": "face-off"
#                     },
#                     {
#                       "wd": "grapple"
#                     },
#                     {
#                       "wd": "match"
#                     },
#                     {
#                       "wd": "rivalry"
#                     },
#                     {
#                       "wd": "strife"
#                     },
#                     {
#                       "wd": "struggle"
#                     },
#                     {
#                       "wd": "sweepstakes",
#                       "wvrs": [
#                         {
#                           "wvl": "also",
#                           "wva": "sweep-stake"
#                         }
#                       ]
#                     },
#                     {
#                       "wd": "tug-of-war"
#                     },
#                     {
#                       "wd": "warfare"
#                     }
#                   ]
#                 ],
#                 "rel_list": [
#                   [
#                     {
#                       "wd": "horse race"
#                     },
#                     {
#                       "wd": "nail-biter"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "showdown"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "clash"
#                     },
#                     {
#                       "wd": "collision"
#                     },
#                     {
#                       "wd": "discord"
#                     },
#                     {
#                       "wd": "friction"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "argument"
#                     },
#                     {
#                       "wd": "controversy"
#                     },
#                     {
#                       "wd": "debate"
#                     },
#                     {
#                       "wd": "disagreement"
#                     },
#                     {
#                       "wd": "disputation"
#                     },
#                     {
#                       "wd": "dispute"
#                     },
#                     {
#                       "wd": "dissension",
#                       "wvrs": [
#                         {
#                           "wvl": "also",
#                           "wva": "dissention"
#                         }
#                       ]
#                     },
#                     {
#                       "wd": "quarrel"
#                     },
#                     {
#                       "wd": "row"
#                     },
#                     {
#                       "wd": "wrangle"
#                     }
#                   ]
#                 ],
#                 "near_list": [
#                   [
#                     {
#                       "wd": "concord"
#                     },
#                     {
#                       "wd": "harmony"
#                     },
#                     {
#                       "wd": "peace"
#                     }
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "shortdef": [
#       "a state of armed violent struggle between states, nations, or groups",
#       "a lack of agreement or harmony",
#       "an earnest effort for superiority or victory over another"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war",
#       "uuid": "95c9e1dd-1e68-4b88-b9fb-e32046a18770",
#       "src": "CTcompile",
#       "section": "alpha",
#       "stems": [
#         "war"
#       ],
#       "syns": [
#         [
#           "battle",
#           "contend",
#           "fight",
#           "oppose",
#           "resist",
#           "withstand",
#           "conserve",
#           "preserve",
#           "save",
#           "avert",
#           "prevent",
#           "buffer",
#           "palisade",
#           "picket",
#           "wall",
#           "bulwark",
#           "cover",
#           "defend",
#           "fence",
#           "fend",
#           "forfend",
#           "guard",
#           "keep",
#           "protect",
#           "safeguard",
#           "screen",
#           "secure",
#           "shield",
#           "ward"
#         ]
#       ],
#       "ants": [
#         [
#           "assail",
#           "assault",
#           "attack",
#           "bombard",
#           "storm",
#           "beset",
#           "besiege",
#           "overrun",
#           "capitulate",
#           "cave",
#           "submit",
#           "yield"
#         ]
#       ],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war"
#     },
#     "fl": "verb",
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "as in {it}fight{/it}, {it}battle{/it}"
#                   ]
#                 ],
#                 "sim_list": [
#                   [
#                     {
#                       "wd": "battle"
#                     },
#                     {
#                       "wd": "contend"
#                     },
#                     {
#                       "wd": "fight"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "oppose"
#                     },
#                     {
#                       "wd": "resist"
#                     },
#                     {
#                       "wd": "withstand"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "conserve"
#                     },
#                     {
#                       "wd": "preserve"
#                     },
#                     {
#                       "wd": "save"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "avert"
#                     },
#                     {
#                       "wd": "prevent"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "buffer"
#                     },
#                     {
#                       "wd": "palisade"
#                     },
#                     {
#                       "wd": "picket"
#                     },
#                     {
#                       "wd": "wall"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "bulwark"
#                     },
#                     {
#                       "wd": "cover"
#                     },
#                     {
#                       "wd": "defend"
#                     },
#                     {
#                       "wd": "fence"
#                     },
#                     {
#                       "wd": "fend"
#                     },
#                     {
#                       "wd": "forfend"
#                     },
#                     {
#                       "wd": "guard"
#                     },
#                     {
#                       "wd": "keep"
#                     },
#                     {
#                       "wd": "protect"
#                     },
#                     {
#                       "wd": "safeguard"
#                     },
#                     {
#                       "wd": "screen"
#                     },
#                     {
#                       "wd": "secure"
#                     },
#                     {
#                       "wd": "shield"
#                     },
#                     {
#                       "wd": "ward"
#                     }
#                   ]
#                 ],
#                 "opp_list": [
#                   [
#                     {
#                       "wd": "assail"
#                     },
#                     {
#                       "wd": "assault"
#                     },
#                     {
#                       "wd": "attack"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "bombard"
#                     },
#                     {
#                       "wd": "storm"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "beset"
#                     },
#                     {
#                       "wd": "besiege"
#                     },
#                     {
#                       "wd": "overrun"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "capitulate"
#                     },
#                     {
#                       "wd": "cave"
#                     },
#                     {
#                       "wd": "submit"
#                     },
#                     {
#                       "wd": "yield"
#                     }
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "shortdef": [
#       "as in fight, battle"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war (against)",
#       "uuid": "dfcf1dd8-9c99-4708-9846-a9ed94ee71aa",
#       "src": "coll_thes",
#       "section": "alpha",
#       "target": {
#         "tuuid": "b519be65-4d79-4cbe-9696-981d36f51e0d",
#         "tsrc": "collegiate"
#       },
#       "stems": [
#         "war (against)",
#         "war",
#         "war against",
#         "warred",
#         "warring",
#         "wars"
#       ],
#       "syns": [
#         [
#           "battle",
#           "clash (with)",
#           "combat",
#           "fight",
#           "scrimmage (with)",
#           "skirmish (with)"
#         ]
#       ],
#       "ants": [],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war (against)"
#     },
#     "fl": "verb",
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "to oppose (someone) in physical conflict "
#                   ],
#                   [
#                     "vis",
#                     [
#                       {
#                         "t": "continually {it}warring against{/it} their neighbors in an effort to expand their territory"
#                       }
#                     ]
#                   ]
#                 ],
#                 "syn_list": [
#                   [
#                     {
#                       "wd": "battle"
#                     },
#                     {
#                       "wd": "clash (with)"
#                     },
#                     {
#                       "wd": "combat"
#                     },
#                     {
#                       "wd": "fight"
#                     },
#                     {
#                       "wd": "scrimmage (with)"
#                     },
#                     {
#                       "wd": "skirmish (with)"
#                     }
#                   ]
#                 ],
#                 "rel_list": [
#                   [
#                     {
#                       "wd": "duel"
#                     },
#                     {
#                       "wd": "joust"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "bang"
#                     },
#                     {
#                       "wd": "bash"
#                     },
#                     {
#                       "wd": "bat"
#                     },
#                     {
#                       "wd": "batter"
#                     },
#                     {
#                       "wd": "beat"
#                     },
#                     {
#                       "wd": "belt"
#                     },
#                     {
#                       "wd": "bludgeon"
#                     },
#                     {
#                       "wd": "bop"
#                     },
#                     {
#                       "wd": "buffet"
#                     },
#                     {
#                       "wd": "clobber"
#                     },
#                     {
#                       "wd": "hammer"
#                     },
#                     {
#                       "wd": "hit"
#                     },
#                     {
#                       "wd": "knock"
#                     },
#                     {
#                       "wd": "paste"
#                     },
#                     {
#                       "wd": "pound"
#                     },
#                     {
#                       "wd": "punch"
#                     },
#                     {
#                       "wd": "slam"
#                     },
#                     {
#                       "wd": "slap"
#                     },
#                     {
#                       "wd": "slog"
#                     },
#                     {
#                       "wd": "slug"
#                     },
#                     {
#                       "wd": "smack"
#                     },
#                     {
#                       "wd": "smite"
#                     },
#                     {
#                       "wd": "sock"
#                     },
#                     {
#                       "wd": "strike"
#                     },
#                     {
#                       "wd": "swat"
#                     },
#                     {
#                       "wd": "swipe"
#                     },
#                     {
#                       "wd": "thump"
#                     },
#                     {
#                       "wd": "thwack"
#                     },
#                     {
#                       "wd": "wallop"
#                     },
#                     {
#                       "wd": "whack"
#                     },
#                     {
#                       "wd": "whale"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "box"
#                     },
#                     {
#                       "wd": "spar"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "brawl"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "grapple"
#                     },
#                     {
#                       "wd": "scuffle"
#                     },
#                     {
#                       "wd": "tussle"
#                     },
#                     {
#                       "wd": "wrestle"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "bump"
#                     },
#                     {
#                       "wd": "collide"
#                     }
#                   ]
#                 ],
#                 "near_list": [
#                   [
#                     {
#                       "wd": "give up"
#                     },
#                     {
#                       "wd": "submit"
#                     },
#                     {
#                       "wd": "surrender"
#                     }
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "shortdef": [
#       "to oppose (someone) in physical conflict"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war hawk",
#       "uuid": "bb52cf90-0a19-479d-b38c-13784a4815e5",
#       "src": "coll_thes",
#       "section": "alpha",
#       "target": {
#         "tuuid": "cb8ef794-b265-4e2b-a1f4-3fd7c29760b5",
#         "tsrc": "collegiate"
#       },
#       "stems": [
#         "war hawk",
#         "war hawks"
#       ],
#       "syns": [
#         [
#           "hawk",
#           "jingo",
#           "jingoist",
#           "militarist",
#           "warmonger"
#         ]
#       ],
#       "ants": [
#         [
#           "dove",
#           "pacifist",
#           "peacenik"
#         ]
#       ],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war hawk"
#     },
#     "fl": "noun",
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "one who urges or attempts to cause a war "
#                   ],
#                   [
#                     "vis",
#                     [
#                       {
#                         "t": "{it}war hawks{/it} in the cabinet who urged the President to respond to the threat with armed force"
#                       }
#                     ]
#                   ]
#                 ],
#                 "syn_list": [
#                   [
#                     {
#                       "wd": "hawk"
#                     },
#                     {
#                       "wd": "jingo"
#                     },
#                     {
#                       "wd": "jingoist"
#                     },
#                     {
#                       "wd": "militarist"
#                     },
#                     {
#                       "wd": "warmonger"
#                     }
#                   ]
#                 ],
#                 "rel_list": [
#                   [
#                     {
#                       "wd": "agitator"
#                     },
#                     {
#                       "wd": "firebrand"
#                     },
#                     {
#                       "wd": "fomenter"
#                     },
#                     {
#                       "wd": "instigator"
#                     },
#                     {
#                       "wd": "rabble-rouser"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "belligerent"
#                     },
#                     {
#                       "wd": "combatant"
#                     },
#                     {
#                       "wd": "militant"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "chauvinist"
#                     }
#                   ]
#                 ],
#                 "near_list": [
#                   [
#                     {
#                       "wd": "peacemaker"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "peacekeeper"
#                     }
#                   ]
#                 ],
#                 "ant_list": [
#                   [
#                     {
#                       "wd": "dove"
#                     },
#                     {
#                       "wd": "pacifist"
#                     },
#                     {
#                       "wd": "peacenik"
#                     }
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "shortdef": [
#       "one who urges or attempts to cause a war"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war paint",
#       "uuid": "73a2a97f-7541-4fa1-a332-72ad25577b87",
#       "src": "coll_thes",
#       "section": "alpha",
#       "target": {
#         "tuuid": "6a1cb17a-103a-45fe-91ba-c4db91f1a0ff",
#         "tsrc": "collegiate"
#       },
#       "stems": [
#         "war paint",
#         "war paints"
#       ],
#       "syns": [
#         [
#           "cosmetics",
#           "makeup",
#           "maquillage",
#           "paint"
#         ]
#       ],
#       "ants": [],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war paint"
#     },
#     "fl": "noun",
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "preparations intended to beautify the face "
#                   ],
#                   [
#                     "vis",
#                     [
#                       {
#                         "t": "when I was young, I loved to watch Mom put on her {it}war paint{/it} before a fancy evening out"
#                       }
#                     ]
#                   ]
#                 ],
#                 "syn_list": [
#                   [
#                     {
#                       "wd": "cosmetics"
#                     },
#                     {
#                       "wd": "makeup"
#                     },
#                     {
#                       "wd": "maquillage"
#                     },
#                     {
#                       "wd": "paint"
#                     }
#                   ]
#                 ],
#                 "rel_list": [
#                   [
#                     {
#                       "wd": "greasepaint"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "camo"
#                     },
#                     {
#                       "wd": "camouflage"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "cold cream"
#                     },
#                     {
#                       "wd": "cream"
#                     },
#                     {
#                       "wd": "eye shadow"
#                     },
#                     {
#                       "wd": "kohl"
#                     },
#                     {
#                       "wd": "lipstick"
#                     },
#                     {
#                       "wd": "lotion"
#                     },
#                     {
#                       "wd": "mascara"
#                     },
#                     {
#                       "wd": "oil"
#                     },
#                     {
#                       "wd": "powder"
#                     },
#                     {
#                       "wd": "rouge"
#                     },
#                     {
#                       "wd": "vanishing cream"
#                     }
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "shortdef": [
#       "preparations intended to beautify the face"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war (with)",
#       "uuid": "1ea2fd20-5ced-4cfb-b362-e7182ca75666",
#       "src": "CTcompile",
#       "section": "alpha",
#       "stems": [
#         "war (with)",
#         "war with"
#       ],
#       "syns": [
#         [
#           "battle",
#           "clash (with)",
#           "combat",
#           "fight",
#           "assail",
#           "assault",
#           "attack",
#           "beset",
#           "charge",
#           "rush",
#           "storm",
#           "strike",
#           "encroach",
#           "harass",
#           "infringe",
#           "trespass",
#           "conquer",
#           "crush",
#           "dominate",
#           "overcome",
#           "overpower",
#           "overwhelm",
#           "subdue",
#           "subject",
#           "subjugate",
#           "vanquish",
#           "beleaguer",
#           "besiege",
#           "blockade",
#           "invest",
#           "despoil",
#           "loot",
#           "maraud",
#           "pillage",
#           "plunder",
#           "ransack",
#           "ravage",
#           "sack",
#           "strip",
#           "garrison",
#           "occupy",
#           "foray (into)",
#           "invade",
#           "overrun",
#           "raid"
#         ]
#       ],
#       "ants": [
#         [
#           "defend",
#           "guard",
#           "protect",
#           "safeguard",
#           "shield",
#           "ward",
#           "defy",
#           "oppose",
#           "repel",
#           "resist",
#           "withstand",
#           "capitulate (to)",
#           "cede (to)",
#           "submit (to)",
#           "succumb (to)",
#           "surrender (to)",
#           "yield (to)"
#         ]
#       ],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war (with)"
#     },
#     "fl": "verb",
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "as in {it}fight{/it}, {it}battle{/it}"
#                   ]
#                 ],
#                 "sim_list": [
#                   [
#                     {
#                       "wd": "battle"
#                     },
#                     {
#                       "wd": "clash (with)"
#                     },
#                     {
#                       "wd": "combat"
#                     },
#                     {
#                       "wd": "fight"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "assail"
#                     },
#                     {
#                       "wd": "assault"
#                     },
#                     {
#                       "wd": "attack"
#                     },
#                     {
#                       "wd": "beset"
#                     },
#                     {
#                       "wd": "charge"
#                     },
#                     {
#                       "wd": "rush"
#                     },
#                     {
#                       "wd": "storm"
#                     },
#                     {
#                       "wd": "strike"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "encroach"
#                     },
#                     {
#                       "wd": "harass"
#                     },
#                     {
#                       "wd": "infringe"
#                     },
#                     {
#                       "wd": "trespass"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "conquer"
#                     },
#                     {
#                       "wd": "crush"
#                     },
#                     {
#                       "wd": "dominate"
#                     },
#                     {
#                       "wd": "overcome"
#                     },
#                     {
#                       "wd": "overpower"
#                     },
#                     {
#                       "wd": "overwhelm"
#                     },
#                     {
#                       "wd": "subdue"
#                     },
#                     {
#                       "wd": "subject"
#                     },
#                     {
#                       "wd": "subjugate"
#                     },
#                     {
#                       "wd": "vanquish"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "beleaguer"
#                     },
#                     {
#                       "wd": "besiege"
#                     },
#                     {
#                       "wd": "blockade"
#                     },
#                     {
#                       "wd": "invest"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "despoil"
#                     },
#                     {
#                       "wd": "loot"
#                     },
#                     {
#                       "wd": "maraud"
#                     },
#                     {
#                       "wd": "pillage"
#                     },
#                     {
#                       "wd": "plunder"
#                     },
#                     {
#                       "wd": "ransack"
#                     },
#                     {
#                       "wd": "ravage"
#                     },
#                     {
#                       "wd": "sack"
#                     },
#                     {
#                       "wd": "strip"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "garrison"
#                     },
#                     {
#                       "wd": "occupy"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "foray (into)"
#                     },
#                     {
#                       "wd": "invade"
#                     },
#                     {
#                       "wd": "overrun"
#                     },
#                     {
#                       "wd": "raid"
#                     }
#                   ]
#                 ],
#                 "opp_list": [
#                   [
#                     {
#                       "wd": "defend"
#                     },
#                     {
#                       "wd": "guard"
#                     },
#                     {
#                       "wd": "protect"
#                     },
#                     {
#                       "wd": "safeguard"
#                     },
#                     {
#                       "wd": "shield"
#                     },
#                     {
#                       "wd": "ward"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "defy"
#                     },
#                     {
#                       "wd": "oppose"
#                     },
#                     {
#                       "wd": "repel"
#                     },
#                     {
#                       "wd": "resist"
#                     },
#                     {
#                       "wd": "withstand"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "capitulate (to)"
#                     },
#                     {
#                       "wd": "cede (to)"
#                     },
#                     {
#                       "wd": "submit (to)"
#                     },
#                     {
#                       "wd": "succumb (to)"
#                     },
#                     {
#                       "wd": "surrender (to)"
#                     },
#                     {
#                       "wd": "yield (to)"
#                     }
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "shortdef": [
#       "as in fight, battle"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war cries",
#       "uuid": "83015110-7e71-4e02-8fdd-ae8316b4cb0f",
#       "src": "CTcompile",
#       "section": "alpha",
#       "stems": [
#         "war cries"
#       ],
#       "syns": [
#         [
#           "battle cries",
#           "maxims",
#           "mottoes",
#           "catchwords",
#           "clichés",
#           "expressions",
#           "idioms",
#           "banners",
#           "catchphrases",
#           "cries",
#           "shibboleths",
#           "slogans",
#           "taglines",
#           "watchwords"
#         ]
#       ],
#       "ants": [],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war cries"
#     },
#     "fl": "noun",
#     "sls": [
#       "plural of {d_link|war cry|war cry}"
#     ],
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "as in {it}battle cries{/it}"
#                   ]
#                 ],
#                 "sim_list": [
#                   [
#                     {
#                       "wd": "battle cries"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "maxims"
#                     },
#                     {
#                       "wd": "mottoes",
#                       "wvrs": [
#                         {
#                           "wvl": "also",
#                           "wva": "mottos"
#                         }
#                       ]
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "catchwords"
#                     },
#                     {
#                       "wd": "clichés",
#                       "wvrs": [
#                         {
#                           "wvl": "also",
#                           "wva": "cliches"
#                         }
#                       ]
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "expressions"
#                     },
#                     {
#                       "wd": "idioms"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "banners"
#                     },
#                     {
#                       "wd": "catchphrases"
#                     },
#                     {
#                       "wd": "cries"
#                     },
#                     {
#                       "wd": "shibboleths"
#                     },
#                     {
#                       "wd": "slogans"
#                     },
#                     {
#                       "wd": "taglines"
#                     },
#                     {
#                       "wd": "watchwords"
#                     }
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "shortdef": [
#       "as in battle cries"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war cry",
#       "uuid": "74a27994-e61e-4c40-bb08-7bb21b1ccc77",
#       "src": "CTcompile",
#       "section": "alpha",
#       "stems": [
#         "war cry"
#       ],
#       "syns": [
#         [
#           "battle cry",
#           "maxim",
#           "motto",
#           "catchword",
#           "cliché",
#           "expression",
#           "idiom",
#           "banner",
#           "catchphrase",
#           "cry",
#           "shibboleth",
#           "slogan",
#           "tagline",
#           "watchword"
#         ]
#       ],
#       "ants": [],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war cry"
#     },
#     "fl": "noun",
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "as in {it}battle cry{/it}"
#                   ]
#                 ],
#                 "sim_list": [
#                   [
#                     {
#                       "wd": "battle cry"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "maxim"
#                     },
#                     {
#                       "wd": "motto"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "catchword"
#                     },
#                     {
#                       "wd": "cliché",
#                       "wvrs": [
#                         {
#                           "wvl": "also",
#                           "wva": "cliche"
#                         }
#                       ]
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "expression"
#                     },
#                     {
#                       "wd": "idiom"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "banner"
#                     },
#                     {
#                       "wd": "catchphrase"
#                     },
#                     {
#                       "wd": "cry"
#                     },
#                     {
#                       "wd": "shibboleth"
#                     },
#                     {
#                       "wd": "slogan"
#                     },
#                     {
#                       "wd": "tagline"
#                     },
#                     {
#                       "wd": "watchword"
#                     }
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "shortdef": [
#       "as in battle cry"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war hawks",
#       "uuid": "a0e8317a-4432-4e3c-8ebe-b1975a05c8df",
#       "src": "coll_thes",
#       "section": "alpha",
#       "stems": [
#         "war hawks"
#       ],
#       "syns": [
#         [
#           "hawks",
#           "jingoes",
#           "jingoists",
#           "militarists",
#           "warmongers"
#         ]
#       ],
#       "ants": [
#         [
#           "doves",
#           "pacifists",
#           "peaceniks"
#         ]
#       ],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war hawks"
#     },
#     "fl": "noun",
#     "sls": [
#       "plural of {d_link|war hawk|war hawk}"
#     ],
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "one who urges or attempts to cause a war "
#                   ],
#                   [
#                     "vis",
#                     [
#                       {
#                         "t": "{it}war hawks{/it} in the cabinet who urged the President to respond to the threat with armed force"
#                       }
#                     ]
#                   ]
#                 ],
#                 "syn_list": [
#                   [
#                     {
#                       "wd": "hawks"
#                     },
#                     {
#                       "wd": "jingoes"
#                     },
#                     {
#                       "wd": "jingoists"
#                     },
#                     {
#                       "wd": "militarists"
#                     },
#                     {
#                       "wd": "warmongers"
#                     }
#                   ]
#                 ],
#                 "rel_list": [
#                   [
#                     {
#                       "wd": "agitators"
#                     },
#                     {
#                       "wd": "firebrands"
#                     },
#                     {
#                       "wd": "fomenters"
#                     },
#                     {
#                       "wd": "instigators"
#                     },
#                     {
#                       "wd": "rabble-rousers"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "belligerents"
#                     },
#                     {
#                       "wd": "combatants"
#                     },
#                     {
#                       "wd": "militants"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "chauvinists"
#                     }
#                   ]
#                 ],
#                 "near_list": [
#                   [
#                     {
#                       "wd": "peacemakers"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "peacekeepers"
#                     }
#                   ]
#                 ],
#                 "ant_list": [
#                   [
#                     {
#                       "wd": "doves"
#                     },
#                     {
#                       "wd": "pacifists"
#                     },
#                     {
#                       "wd": "peaceniks"
#                     }
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "shortdef": [
#       "one who urges or attempts to cause a war"
#     ]
#   },
#   {
#     "meta": {
#       "id": "war paints",
#       "uuid": "0aa8daf9-4dd3-47fc-8515-5f869139fbe1",
#       "src": "coll_thes",
#       "section": "alpha",
#       "stems": [
#         "war paints"
#       ],
#       "syns": [
#         [
#           "cosmetics",
#           "makeups",
#           "maquillages",
#           "paints"
#         ]
#       ],
#       "ants": [],
#       "offensive": false
#     },
#     "hwi": {
#       "hw": "war paints"
#     },
#     "fl": "noun",
#     "sls": [
#       "plural of {d_link|war paint|war paint}"
#     ],
#     "def": [
#       {
#         "sseq": [
#           [
#             [
#               "sense",
#               {
#                 "dt": [
#                   [
#                     "text",
#                     "preparations intended to beautify the face "
#                   ],
#                   [
#                     "vis",
#                     [
#                       {
#                         "t": "when I was young, I loved to watch Mom put on her {it}war paint{/it} before a fancy evening out"
#                       }
#                     ]
#                   ]
#                 ],
#                 "syn_list": [
#                   [
#                     {
#                       "wd": "cosmetics"
#                     },
#                     {
#                       "wd": "makeups"
#                     },
#                     {
#                       "wd": "maquillages"
#                     },
#                     {
#                       "wd": "paints"
#                     }
#                   ]
#                 ],
#                 "rel_list": [
#                   [
#                     {
#                       "wd": "greasepaints"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "camos"
#                     },
#                     {
#                       "wd": "camouflages"
#                     }
#                   ],
#                   [
#                     {
#                       "wd": "cold creams"
#                     },
#                     {
#                       "wd": "creams"
#                     },
#                     {
#                       "wd": "eye shadows"
#                     },
#                     {
#                       "wd": "kohls"
#                     },
#                     {
#                       "wd": "lipsticks"
#                     },
#                     {
#                       "wd": "lotions"
#                     },
#                     {
#                       "wd": "mascaras"
#                     },
#                     {
#                       "wd": "oils"
#                     },
#                     {
#                       "wd": "powders"
#                     },
#                     {
#                       "wd": "rouges"
#                     },
#                     {
#                       "wd": "vanishing creams"
#                     }
#                   ]
#                 ]
#               }
#             ]
#           ]
#         ]
#       }
#     ],
#     "shortdef": [
#       "preparations intended to beautify the face"
#     ]
#   }
# ]
