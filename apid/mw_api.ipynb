# %%
from mw.entries_requests import get_data
from mw.helpers import search_results_to_json 
import json

# %% [markdown]
# # Merriam-Webster Collegiate Dictionary

# %%
result = get_data("above", "collegiate")

if result:
    result_json = search_results_to_json(result)
    print(json.dumps(result_json, indent=2, ensure_ascii=False))
# Out:
# 10
# {
#   "1": {
#     "headword": "over and above",
#     "variants": [],
#     "functional_labels": "preposition",
#     "general_labels": [],
#     "definitions": [
#       {
#         "vd": "",
#         "senses": [
#           {
#             "defining_text": [
#               {
#                 "text": "{bc}in addition to {bc}{sx|besides||}"
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   },
#   "2": {
#     "headword": "above",
#     "variants": [],
#     "functional_labels": "preposition",
#     "general_labels": [],
#     "definitions": [
#       {
#         "vd": "",
#         "senses": [
#           {
#             "sense_nr": "1 a",
#             "defining_text": [
#               {
#                 "text": "{bc}in or to a higher place than {bc}{sx|over||} "
#               },
#               {
#                 "verbal_illustrations": [
#                   {
#                     "t": "a room {wi}above{/wi} the store"
# ...

# %% [markdown]
# # Merriam-Webster Collegiate Thesaurus

# %%
result = get_data("war", "thesaurus")

if result:

    print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "meta": {
#       "id": "war",
#       "uuid": "db4a6ea1-f3c6-448c-b26f-4a87375e6452",
#       "src": "coll_thes",
#       "section": "alpha",
#       "target": {
#         "tuuid": "375c6df5-d281-4811-9a53-a31096f8c9f0",
#         "tsrc": "collegiate"
#       },
#       "stems": [
#         "war",
#         "warless",
#         "wars"
#       ],
#       "syns": [
#         [
#           "conflagration",
#           "conflict",
#           "hostilities",
#           "hot war"
#         ],
#         [
#           "conflict",
#           "disaccord",
#           "discord",
#           "discordance",
#           "discordancy",
#           "disharmony",
#           "dissension",
#           "dissent",
#           "dissidence",
#           "dissonance",
#           "disunion",
#           "disunity",
#           "division",
#           "friction",
#           "infighting",
#           "inharmony",
#           "schism",
#           "strife",
#           "variance",
# ...
